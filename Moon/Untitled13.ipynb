# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plot
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
customer_churn = pd.read_csv("C:/Users/Arunima/Downloads/chrun.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/1850069638.py in <module>
# ----> 1 customer_churn = pd.read_csv("C:/Users/Arunima/Downloads/chrun.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
customer_churn = pd.read_csv("C:/Users/Arunima/Downloads/churn.csv")

# %%
print(customer_churn)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 0             1  8260-NGFNY    One  Month-to-month               No
# 1             2  2359-QWQUL     39        One year              Yes
# 2             3  6598/RFFVI      2        One year               No
# 3             4  IXSTS-8780      6  Month-to-month              Yes
# 4             5  2674/MIAHT   Four  Month-to-month              Yes
# ..          ...         ...    ...             ...              ...
# 252         253  9318-NKNFC    One  Month-to-month              Yes
# 253         254  9067-SQTNS     44        One year               No
# 254         255  9067-SQTNS     44        One year               No
# 255         256  9067-SQTNS     44        One year               No
# 256         257  9067-SQTNS     44        One year               No
#
#                  PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0                 Mailed check           25.20         25.20  Female
# ...

# %% [markdown]
# customer_churn(head)

# %%
customer_churn.head()
# Out:
#    Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 0           1  8260-NGFNY    One  Month-to-month               No
# 1           2  2359-QWQUL     39        One year              Yes
# 2           3  6598/RFFVI      2        One year               No
# 3           4  IXSTS-8780      6  Month-to-month              Yes
# 4           5  2674/MIAHT   Four  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0             Mailed check            25.2         25.20  Female
# 1  Credit card (automatic)           104.7       4134.85  Female
# 2  Credit card (automatic)            19.3         28.30    Male
# 3         Electronic check            90.1        521.30  Female
# 4             Mailed check            80.3        324.20  Female
#
#    SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 0            0.0  ...           No  No phone service             DSL
# ...

# %%
customer_chrun.iloc[:,4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/3150522295.py in <module>
# ----> 1 customer_chrun.iloc[:,4]
#
# NameError: name 'customer_chrun' is not defined

# %%
c_15 = customer_chrun.iloc[:,4]
c_15.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2054816615.py in <module>
# ----> 1 c_15 = customer_chrun.iloc[:,4]
#       2 c_15.head(5)
#
# NameError: name 'customer_chrun' is not defined

# %%
c_15 = customer_chrun.iloc[:,4]
c_15.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/189215865.py in <module>
# ----> 1 c_15 = customer_chrun.iloc[:,4]
#       2 c_15.head()
#
# NameError: name 'customer_chrun' is not defined

# %%
c_15 = customer_chrun.iloc[:,14]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2483582444.py in <module>
# ----> 1 c_15 = customer_chrun.iloc[:,14]
#
# NameError: name 'customer_chrun' is not defined

# %%
c_15 = customer_churn.iloc[:,4]
c_15.head()
# Out:
# 0     No
# 1    Yes
# 2     No
# 3    Yes
# 4    Yes
# Name: PaperlessBilling, dtype: object

# %%
customer_churn
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 0             1  8260-NGFNY    One  Month-to-month               No
# 1             2  2359-QWQUL     39        One year              Yes
# 2             3  6598/RFFVI      2        One year               No
# 3             4  IXSTS-8780      6  Month-to-month              Yes
# 4             5  2674/MIAHT   Four  Month-to-month              Yes
# ..          ...         ...    ...             ...              ...
# 252         253  9318-NKNFC    One  Month-to-month              Yes
# 253         254  9067-SQTNS     44        One year               No
# 254         255  9067-SQTNS     44        One year               No
# 255         256  9067-SQTNS     44        One year               No
# 256         257  9067-SQTNS     44        One year               No
#
#                  PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0                 Mailed check           25.20         25.20  Female
# ...

# %%
c_random = customer_churn[(customer_churn[gender== "Male"])& customer_churn(customer_churn[payment_method=="Bank transfer"])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/7345689.py in <module>
# ----> 1 c_random = customer_churn[(customer_churn[gender== "Male"])& customer_churn(customer_churn[payment_method=="Bank transfer"])]
#
# NameError: name 'gender' is not defined

# %%
c_random = customer_churn[(customer_churn[gender== "Male"])& customer_churn(customer_churn[payment_method=="Bank transfer"])] = customer_churn[(customer_churn["gender"== "Male"])& customer_churn(customer_churn["payment_method"=="Bank transfer"])]

# %%
c_random.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/1326590410.py in <module>
# ----> 1 c_random.head()
#
# NameError: name 'c_random' is not defined

# %%
c_random.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/1326590410.py in <module>
# ----> 1 c_random.head()
#
# NameError: name 'c_random' is not defined

# %%
c_random
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/133351201.py in <module>
# ----> 1 c_random
#
# NameError: name 'c_random' is not defined

# %%
c_random.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/1326590410.py in <module>
# ----> 1 c_random.head()
#
# NameError: name 'c_random' is not defined

# %%
c_random = customer_churn[(customer_churn[gender== "Male"])& customer_churn(customer_churn[payment_method=="Bank transfer"])] = customer_churn[(customer_churn["gender"== "Male"])& customer_churn(customer_churn["payment_method"=="Bank transfer"])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
c_random = customer_churn[(customer_churn["gender"== "Male"])& customer_churn(customer_churn["payment_method"=="Bank transfer"])] = customer_churn[(customer_churn["gender"== "Male"])& customer_churn(customer_churn["payment_method"=="Bank transfer"])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
c_random = customer_churn[(customer_churn['gender']=="Male")&(customer_churn['PaymentMethod']=="Bank transfer")]

# %%
c_random = customer_churn[(customer_churn['gender']=="Male")]

# %%
c_random.head()
# Out:
#    Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 2           3  6598/RFFVI      2        One year               No
# 6           7  7929/SKFGK     70        Two year               No
# 7           8  7547-EKNFS     42  Month-to-month              Yes
# 8           9  5854-KSRBJ     70        Two year               No
# 9          10  5054-IEXZT    One  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges gender  \
# 2    Credit card (automatic)           19.30         28.30   Male
# 6    Credit card (automatic)          114.30       8244.30   Male
# 7  Bank transfer (automatic)           95.25       3959.35   Male
# 8               Mailed check           25.40       1782.05   Male
# 9           Electronic check           75.35         75.35   Male
#
#    SeniorCitizen  ... PhoneService MultipleLines InternetService  \
# 2            0.0  ...          Yes            No              No
# ...

# %%
c_random = customer_churn[(customer_churn['gender']=="Male")]

# %%
c_random.head()
# Out:
#    Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 2           3  6598/RFFVI      2        One year               No
# 6           7  7929/SKFGK     70        Two year               No
# 7           8  7547-EKNFS     42  Month-to-month              Yes
# 8           9  5854-KSRBJ     70        Two year               No
# 9          10  5054-IEXZT    One  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges gender  \
# 2    Credit card (automatic)           19.30         28.30   Male
# 6    Credit card (automatic)          114.30       8244.30   Male
# 7  Bank transfer (automatic)           95.25       3959.35   Male
# 8               Mailed check           25.40       1782.05   Male
# 9           Electronic check           75.35         75.35   Male
#
#    SeniorCitizen  ... PhoneService MultipleLines InternetService  \
# 2            0.0  ...          Yes            No              No
# ...

# %%
c_random=[customer_churn(customer_churn['tenure']>70) & (customer_churn["MonthlyCharges"]>100.00)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/160325973.py in <module>
# ----> 1 c_random=[customer_churn(customer_churn['tenure']>70) & (customer_churn["MonthlyCharges"]>100.00)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random=[customer_churn(customer_churn['tenure']>70) & (customer_churn['MonthlyCharges']>100.00)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2580879104.py in <module>
# ----> 1 c_random=[customer_churn(customer_churn['tenure']>70) & (customer_churn['MonthlyCharges']>100.00)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random=[customer_churn(customer_churn['tenure']>70) | (customer_churn['MonthlyCharges']>100.00)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2357734253.py in <module>
# ----> 1 c_random=[customer_churn(customer_churn['tenure']>70) | (customer_churn['MonthlyCharges']>100.00)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random=customer_churn[customer_churn(customer_churn['tenure']>70) | (customer_churn['MonthlyCharges']>100.00)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/3154025504.py in <module>
# ----> 1 c_random=customer_churn[customer_churn(customer_churn['tenure']>70) | (customer_churn['MonthlyCharges']>100.00)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random= customer_churn[customer_churn(['tenure']>70)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2731045694.py in <module>
# ----> 1 c_random= customer_churn[customer_churn(['tenure']>70)]
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
c_random= customer_churn[(customer_churn['tenure']>70)| (customer_churn['MonthlyCharges']>100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/675044539.py in <module>
# ----> 1 c_random= customer_churn[(customer_churn['tenure']>70)| (customer_churn['MonthlyCharges']>100)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random= customer_churn[(customer_churn['tenure']>70)| (customer_churn['MonthlyCharges']>100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/675044539.py in <module>
# ----> 1 c_random= customer_churn[(customer_churn['tenure']>70)| (customer_churn['MonthlyCharges']>100)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
c_random= customer_churn[(customer_churn['MonthlyCharges']>100)]

# %%
c_random.head()
# Out:
#     Unnamed: 0  customerID tenure  Contract PaperlessBilling  \
# 1            2  2359-QWQUL     39  One year              Yes
# 6            7  7929/SKFGK     70  Two year               No
# 12          13  3325-FUYCG     28  One year               No
# 27          28  1090-PYKCI     69  One year              Yes
# 28          29  6362-QHAFM     42  One year              Yes
#
#               PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 1   Credit card (automatic)           104.7       4134.85  Female
# 6   Credit card (automatic)           114.3       8244.30    Male
# 12         Electronic check           106.1       2847.40    Male
# 27  Credit card (automatic)           105.1       7234.80  Female
# 28         Electronic check           108.3       4586.15    Male
#
#     SeniorCitizen  ... PhoneService MultipleLines InternetService  \
# 1             0.0  ...          Yes            No     Fiber optic
# ...

# %%
c_random=customer_churn[(customer_churn['Contract']=="Two year") & (customer_churn['PaymentMethod']=="Mailed Check") & (customer_churn['Churn']=="Yes")]

# %%
c_random.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_random=customer_churn[(customer_churn['Contract']=="Two year") & (customer_churn['PaymentMethod']=="Mailed Check")]

# %%
c_random.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_random=customer_churn[(customer_churn['PaymentMethod']=="Mailed Check")]

# %%
c_random.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_random=customer_churn[(customer_churn['Contract']=="One year") & (customer_churn['PaymentMethod']=="Credit card")]

# %%
c_random
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_random=customer_churn[(customer_churn['Contract'] == "Two year") & (customer_churn['PaymentMethod'] == "Mailed Check")]

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_333 =customer_churn.sample(n=333)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/2890949754.py in <module>
# ----> 1 c_333 =customer_churn.sample(n=333)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
customer_churn['Contract'].value_counts()
# Out:
# Month-to-month    133
# One year           62
# Two year           62
# Name: Contract, dtype: int64
