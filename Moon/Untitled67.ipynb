# %%
1. Display Student Name using array 
2. Print list of range from 4 to 30 
3. Print Maximum value from a list 
4. Print First 10 natural number
5. Remove duplicates from a list and create a tuple and find the minimum and maximum number
6. Remove items from a list while iterating
7. Reverse each word of a string
8. Reverse Dictionary mapping
9. Display all duplicate items from a list
10.Filter dictionary to contain keys present in the given list
11.Print the following number pattern
12.Create an inner function
13.Modify the element of a nested list inside the following list
14. Access the nested key increment from the following dictionary
15. Append an element in Tuple at end
16. Insert an element at specific position in tuple
17. Modify / Replace the element at specific index in tuple
18. Delete an element at specific index in tuple
19. Pandas Tutorial Part #1 - Introduction to Data Analysis with Python
20. Pandas Tutorial Part #2 - Basics of Pandas Series
21. Pandas Tutorial Part #3 - Get & Set Series values
Pandas Tutorial Part #4 - Attributes & methods of Pandas Series
Pandas Tutorial Part #5 - Add or Remove Pandas Series elements
Pandas Tutorial Part #6 - Introduction to DataFrame
Pandas Tutorial Part #7 - DataFrame.loc[] - Select Rows / Columns by Indexing
Pandas Tutorial Part #8 - DataFrame.iloc[] - Select Rows / Columns by Label Names
Pandas Tutorial Part #9 - Filter DataFrame Rows
Pandas Tutorial Part #10 - Add/Remove DataFrame Rows & Columns
Pandas Tutorial Part #11 - DataFrame attributes & methods
Pandas Tutorial Part #12 - Handling Missing Data or NaN values
Pandas Tutorial Part #13 - Iterate over Rows & Columns of DataFrame
Pandas Tutorial Part #14 - Sorting DataFrame by Rows or Columns
Pandas Tutorial Part #15 - Merging or Concatenating DataFrames
Pandas Tutorial Part #16 - DataFrame GroupBy explained with examples
Convert a String to Lowercase in Python
How to Convert a String to int in Python?
How to convert a string to a boolean in Python?
How to compare strings in Python? (‘is’ vs ‘==’)
Check if a substring is in list of strings in Python
How to Append Strings in Python?
Check if a string contains a number in Python
How to Read Input from stdin in Python?
How to iterate over a JSON object in Python?
How to remove a trailing newline in Python?
What is “yield” keyword in Python? – Complete Guide
How to manually raise / throw an exception in Python?
How to use “not equal” operator in Python?
Print NumPy Array without scientific notation in Python
Matrix Vector multiplication using NumPy in Python
How to check NumPy Version in Python?
How to create an empty NumPy Array in Python?
Compare two NumPy Arrays element-wise in Python
Add Column to Pandas DataFrame with constant value
How to Check if a Pandas Column contains a value?
Python write a list to CSV row
Python write a list to CSV header
Python write a list to CSV pandas
Python write a list to CSV numpy
Python write a list to CSV newline
Python write a nested list to CSV
Python write a list of list to CSV
Python append a list to CSV
Python write a list to CSV column
sum of number using a loop 
sum of first ten number by using range
product of first ten number 
i) if 500 is greater than number 
ii) number is divisible by 5
iii) if number is greater than 150 then continue
count the number of total dight in 
iterating through reverse a list
merge two dictionary
sum of series (n = 5, start = 2)
input_number = 6, cube of each input_number
reverse a loop by given a range from 10 to 1
To check a number whether the key exists or not in diretory 
print key and value in Dictionary
Print key in Dictionary
print value in Dictionary
print merge two dictionary
Merge two list into Dictionary
sort dictionary 
reverse the list
Merge two dictionary into one
Sum of above series with n = 5 and start =2 
Iterate through a list by using [1::2]
reversed the given number 1234
reverse a string 
prime number within a range 25 to 30
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_1848/694975527.py", line 6
#     if array3 = [2,3,4,2,0,0]:
#               ^
# SyntaxError: invalid syntax
