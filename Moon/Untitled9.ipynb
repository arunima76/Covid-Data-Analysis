# %%
GEEK = {'g', 'e', 'k'}

# %%
GEEK.add('s')

# %%
print('Letters are:', GEEK)
# Out:
# Letters are: {'g', 'e', 's', 'k'}

# %%
GEEK.add('s')

# %%
print('Letters are:', GEEK)
# Out:
# Letters are: {'g', 'e', 's', 'k'}

# %%
import pandas as pd

# %%
data= pd.read_csv("C:/Users/Arunima/Downloads/csv.csv")

# %%
print(data)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
short_data = data.head()

# %%
short_data = data.head(5)

# %%
list = [1,2,3,4,5]

# %%
short_data["Added Values"]=short_data["Salary"].add(list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
short_data["Added Values"]=short_data["Salary"].add(list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
short_data["Added values"]= short_data["Value"].add(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/2807346791.py in <module>
# ----> 1 short_data["Added values"]= short_data["Value"].add(list)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     187                 raise ValueError("Lengths must be equal")
#     188             other = self._constructor(other, self.index)
# --> 189             result = self._binop(other, op, level=level, fill_value=fill_value)
#     190             result.name = res_name
#     191             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _binop(self, other, func, level, fill_value)
#    2909
#    2910         with np.errstate(all="ignore"):
# -> 2911             result = func(this_vals, other_vals)
#    2912
# ...

# %%
short_data["Added values"]= short_data["Value"].add(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/2807346791.py in <module>
# ----> 1 short_data["Added values"]= short_data["Value"].add(list)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     187                 raise ValueError("Lengths must be equal")
#     188             other = self._constructor(other, self.index)
# --> 189             result = self._binop(other, op, level=level, fill_value=fill_value)
#     190             result.name = res_name
#     191             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _binop(self, other, func, level, fill_value)
#    2909
#    2910         with np.errstate(all="ignore"):
# -> 2911             result = func(this_vals, other_vals)
#    2912
# ...

# %%
import pandas as pd

# %%
data= pd.read_csv("C:/Users/Arunima/gfg.csv")

# %%
short_data= data.head()

# %%
data
# Out:
#     Unnamed: 0    id                 name                               email  \
# 0            0  4051                manoj                     manoj@gmail.com
# 1            1  4050               pankaj                        p1@gmail.com
# 2            2  3050           Neeraj1993   neeraj.singh@adequateinfosoft.com
# 3            3  3049               Sophia                    sophia@gmail.com
# 4            4  3048          Raju Prasad                 raju.nsit@gmail.com
# 5            5  3047    Ankiish Thapliyal       thapliyalankiish958@gmail.com
# 6            6  3046      Aryan Thapliyal            ashithewarrior@gmail.com
# 7            7  3045               shivam                    shivam@gmail.com
# 8            8  3044       Navya Upadhyay            navya.adequate@gmail.com
# 9            9  3043           Ritu singh         ritusinghadequate@gmail.com
# 10          10  3042                 faiz              faizadequate@gmail.com
# ...

# %%
data(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/644005431.py in <module>
# ----> 1 data(head)
#
# NameError: name 'head' is not defined

# %%
data.head()
# Out:
#    Unnamed: 0    id         name                              email  \
# 0           0  4051        manoj                    manoj@gmail.com
# 1           1  4050       pankaj                       p1@gmail.com
# 2           2  3050   Neeraj1993  neeraj.singh@adequateinfosoft.com
# 3           3  3049       Sophia                   sophia@gmail.com
# 4           4  3048  Raju Prasad                raju.nsit@gmail.com
#
#     password                      about                                 token  \
# 0   Test@123                        NaN  7f471974-ae46-4ac0-a882-1980c300c4d6
# 1   Test@123                        NaN  e269eeef-1de1-4438-885a-e30a9ad26106
# 2     286956                        NaN  562c2fb5-6799-4b51-8733-a60564c96adc
# 3   Test@123                         Yo  f3bc9393-ad13-41a2-a69b-b607a42d829f
# 4  Raju@1234  Don't Quit Your Day Dream  b3eda104-0771-4804-8be2-0e6d7c16412d
#
#    country                                           location  lng  ...  \
# ...

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/947105821.py in <module>
# ----> 1 short.data = data.head
#
# NameError: name 'short' is not defined

# %%
short_data = data.head

# %%
list =[1, 2, 3, 4, 5]

# %%
short_data["Added values"]= short_data["Salary"].add(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/730810729.py in <module>
# ----> 1 short_data["Added values"]= short_data["Salary"].add(list)
#
# TypeError: 'method' object is not subscriptable

# %%
short_data
# Out:
# <bound method NDFrame.head of     Unnamed: 0    id                 name                               email  \
# 0            0  4051                manoj                     manoj@gmail.com
# 1            1  4050               pankaj                        p1@gmail.com
# 2            2  3050           Neeraj1993   neeraj.singh@adequateinfosoft.com
# 3            3  3049               Sophia                    sophia@gmail.com
# 4            4  3048          Raju Prasad                 raju.nsit@gmail.com
# 5            5  3047    Ankiish Thapliyal       thapliyalankiish958@gmail.com
# 6            6  3046      Aryan Thapliyal            ashithewarrior@gmail.com
# 7            7  3045               shivam                    shivam@gmail.com
# 8            8  3044       Navya Upadhyay            navya.adequate@gmail.com
# 9            9  3043           Ritu singh         ritusinghadequate@gmail.com
# 10          10  3042                 faiz              faizadequate@gmail.com
# ...

# %%
set 1 = {1,2,3,4,5}
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/1003264650.py", line 1
#     set 1 = {1,2,3,4,5}
#         ^
# SyntaxError: invalid syntax

# %%
set1 = {1,2,3,4,5}

# %%
print "First set are," set1
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/889794803.py", line 1
#     print "First set are," set1
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("First set are," set1)?

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/2575910618.py in <module>
# ----> 1 set1(0)
#
# TypeError: 'set' object is not callable

# %%
set1(0).add= set1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/3430664491.py in <module>
# ----> 1 set1(0).add= set1
#
# TypeError: 'set' object is not callable

# %%
set1(0).add
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/3121504222.py in <module>
# ----> 1 set1(0).add
#
# TypeError: 'set' object is not callable

# %%
print "Remove duplicate in a list"
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/1348454707.py", line 1
#     print "Remove duplicate in a list"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Remove duplicate in a list")?

# %%
print( "Remove duplicate in a list")
# Out:
# Remove duplicate in a list

# %%
List = [8,7,6,5,5,4,4,4,3]

# %%
dedulpicated_list = list(set(duplicated_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/240973660.py in <module>
# ----> 1 dedulpicated_list = list(set(duplicated_list))
#
# NameError: name 'duplicated_list' is not defined

# %%
dulpicated_list = list(set(List))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/2875846664.py in <module>
# ----> 1 dulpicated_list = list(set(List))
#
# TypeError: 'list' object is not callable

# %%
duplicated_list = [1,1,2,1,3,4,1,2,3,4]
deduplicated_list = list(set(duplicated_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/3768564860.py in <module>
#       1 duplicated_list = [1,1,2,1,3,4,1,2,3,4]
# ----> 2 deduplicated_list = list(set(duplicated_list))
#
# TypeError: 'list' object is not callable

# %%
import pandas as pd

# %%
duplicated_list=[1,1,2,3,4,7,8,8]

# %%
deduplicated_list = pd.Series(duplicated_list).unique().tolist()

# %%
print(deduplicated_list)
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
string = "geeksforheek"

# %%
p =""

# %%
for char in string:
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/3408121275.py", line 1
#     for char in string:
#                        ^
# IndentationError: expected an indented block

# %%
string="geeksforgeeks"
p=""
for char in string:
    if char not in p:
        p=p+char
print(p)
# Out:
# geksfor

# %%
import pandas as pd

# %%
df_gomes=("C:/Users/Arunima/gfg.csv")

# %%
df_gomes=['Inspected']=false
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/4226986779.py", line 1
#     df_gomes=['Inspected']=false
#               ^
# SyntaxError: cannot assign to literal

# %%
df_gomes['Inspected']=false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/1868649401.py in <module>
# ----> 1 df_gomes['Inspected']=false
#
# NameError: name 'false' is not defined

# %%
df_gomes['Inspected']='false'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/846101475.py in <module>
# ----> 1 df_gomes['Inspected']='false'
#
# TypeError: 'str' object does not support item assignment

# %%
df_gomes['Inspected']= "false"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/3142504775.py in <module>
# ----> 1 df_gomes['Inspected']= "false"
#
# TypeError: 'str' object does not support item assignment

# %%
import pandas as pd

# %%
new_col = ['foo', 'bar', 'foo', 'foo', 'bar', 'bar', 'bar']

# %%
print(new_col)
# Out:
# ['foo', 'bar', 'foo', 'foo', 'bar', 'bar', 'bar']

# %%
data_new['new_col'] = new_col
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/2767204606.py in <module>
# ----> 1 data_new['new_col'] = new_col
#
# NameError: name 'data_new' is not defined

# %%
data_new = pd.read_csv('gfg.csv')

# %%
data_new['new_col']= new_col
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/1815801941.py in <module>
# ----> 1 data_new['new_col']= new_col
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
# ...

# %%
data_new.to_csv('data_new.csv')

# %%
data_new['new_col']= new_col
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/1815801941.py in <module>
# ----> 1 data_new['new_col']= new_col
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
# ...

# %%
import pandas as pd

# %%
csv_input = pd.read_csv("gfg.csv")

# %%
print(csv_input)
# Out:
#     Unnamed: 0    id                 name                               email  \
# 0            0  4051                manoj                     manoj@gmail.com
# 1            1  4050               pankaj                        p1@gmail.com
# 2            2  3050           Neeraj1993   neeraj.singh@adequateinfosoft.com
# 3            3  3049               Sophia                    sophia@gmail.com
# 4            4  3048          Raju Prasad                 raju.nsit@gmail.com
# 5            5  3047    Ankiish Thapliyal       thapliyalankiish958@gmail.com
# 6            6  3046      Aryan Thapliyal            ashithewarrior@gmail.com
# 7            7  3045               shivam                    shivam@gmail.com
# 8            8  3044       Navya Upadhyay            navya.adequate@gmail.com
# 9            9  3043           Ritu singh         ritusinghadequate@gmail.com
# 10          10  3042                 faiz              faizadequate@gmail.com
# ...

# %%
print "Add new column into a csv file"
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_5884/1575666057.py", line 1
#     print "Add new column into a csv file"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Add new column into a csv file")?

# %%
print ("Add new column into a csv file")
# Out:
# Add new column into a csv file

# %%
import pandas as pd

# %%
csv_input= pd.read_csv("data_new.csv")

# %%
csv_input["Berries"]= csv_input['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
csv_input.to_csv("output.csv", index= False)

# %%
print(output.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/1751531050.py in <module>
# ----> 1 print(output.csv)
#
# NameError: name 'output' is not defined
